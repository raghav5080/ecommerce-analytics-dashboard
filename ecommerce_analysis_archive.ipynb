# %% [markdown]
# # 🗂️ Archive — Removed & Broken Cells
#
# This notebook contains all cells removed from `ecommerce_analysis_clean.ipynb`.
# These were either broken, had typos, were duplicate attempts, or were superseded by better code.
# Kept here for reference only — **do not run this notebook top to bottom.**
#
# ---

# %% [markdown]
# ### Group 1 — RAW cell (never executes) & failed imports

# %%
# ── ARCHIVED (original cell 1) ──
import pandas as pd
import numpy as np

# %% [markdown]
# ### Group 2 — read_csv attempts without encoding=latin1 (caused errors)

# %%
# ── ARCHIVED (original cell 2) ──
df= pd.read_csv('C:\\Users\\Master Mind Computer\\Downloads\\data.csv\\data.csv)

# %%
# ── ARCHIVED (original cell 3) ──
df = pd.read_csv(r"C:\Users\Master Mind Computer\Downloads\data.csv\data.csv")

# %%
# ── ARCHIVED (original cell 4) ──
df = pd.read_csv(r"C:\Users\Master Mind Computer\Downloads\data.csv\data.csv")

# %%
# ── ARCHIVED (original cell 6) ──
df = pd.read_csv(r"C:\Users\Master Mind Computer\Downloads\data.csv\data.csv")

# %% [markdown]
# ### Group 3 — df.head missing parentheses

# %%
# ── ARCHIVED (original cell 9) ──
df.head

# %% [markdown]
# ### Group 4 — dropna typo: `dropana` instead of `dropna`

# %%
# ── ARCHIVED (original cell 17) ──
df = df.dropana(subset=['CustomerID'])

# %% [markdown]
# ### Group 5 — to_datetime typos

# %%
# ── ARCHIVED (original cell 21) ──
df['InvoiceDate'] = pd.to_date(df['InvoiceDate'])

# %%
# ── ARCHIVED (original cell 22) ──
df['InvoiceDate'] = pd.to_datetime[df['InvoiceDate']]

# %% [markdown]
# ### Group 6 — TotalPrice typo: `Quality` instead of `Quantity`

# %%
# ── ARCHIVED (original cell 24) ──
df['TotalPrice'] =  df['Quality'] * df['UnitPrice']

# %% [markdown]
# ### Group 7 — top_selling_product: dot-bracket syntax errors and sort_value (missing 's') typos

# %%
# ── ARCHIVED (original cell 36) ──
top_selling_product = df.groupby('description').['quantity'].sum().sort_value(ascending=False)

# %%
# ── ARCHIVED (original cell 39) ──
top_selling_product = df.groupby('description').['quantity'].sum().sort_value(ascending=False)

# %%
# ── ARCHIVED (original cell 40) ──
top_selling_product = df.groupby('description')['quantity'].sum().sort_value(ascending=False)

# %%
# ── ARCHIVED (original cell 41) ──
top_selling_product = df.groupby('description').['quantity'].sum().sort_values(ascending=False)

# %%
# ── ARCHIVED (original cell 42) ──
top_selling_product = df.groupby('description')['quantity'].sum().sort_value(ascending=False)

# %% [markdown]
# ### Group 8 — monthly_revenue added as df column instead of separate Series

# %%
# ── ARCHIVED (original cell 47) ──
df['monthly_revenue'] = df.groupby('month')['total_price'].sum()

# %%
# ── ARCHIVED (original cell 48) ──
df.head

# %%
# ── ARCHIVED (original cell 49) ──
df.drop('mothly_revenue', axis=1, inplace=True)

# %% [markdown]
# ### Group 9 — order_value typo: `oder_value`

# %%
# ── ARCHIVED (original cell 54) ──
oder_value = df.groupby('invoice_no')['total_price'].sum()

# %%
# ── ARCHIVED (original cell 56) ──
order_value = oder_value

# %% [markdown]
# ### Group 10 — mothly_customer typo

# %%
# ── ARCHIVED (original cell 62) ──
mothly_customer

# %% [markdown]
# ### Group 11 — pip install in code cell (should be run in terminal)

# %%
# ── ARCHIVED (original cell 74) ──
pip install ipython-sql

# %% [markdown]
# ### Group 12 — seaborn heatmap incomplete (missing pivot calculation)

# %%
# ── ARCHIVED (original cell 77) ──
import seaborn as sns
df['day_of_week'] = df['invoice_date'].dt.day_name()
df['hour']= df['invoice_date'].dt.hour
pivot = df.groupby(['day_of_week' , 'hour'])['total_price'].sum().unstack()

plt.figure(figsize=(14,6))
sns.heatmap(pivot, cmap='YlGnBu')
plt.title('Revenue Heatmap by Day and Hour')
plt.tight_layout()
plt.show

# %% [markdown]
# ### Group 13 — sqlite3 connect with old filename `ecommerce_data.db`

# %%
# ── ARCHIVED (original cell 79) ──
conn = sqlite3.connect('ecommerce_data.db')
df.to_sql('retail_data', conn, if_exists= 'replace', index=False)

# %% [markdown]
# ### Group 14 — month format experiments for Looker Studio compatibility

# %%
# ── ARCHIVED (original cell 90) ──
df['month'] = df['invoice_date'].dt.strftime('%Y-%m')

# %%
# ── ARCHIVED (original cell 91) ──
df.to_csv('cleaned_retail_1.csv', index=False )

# %%
# ── ARCHIVED (original cell 92) ──
df['month'] = df['invoice_date'].dt.strftime('%Y-%m-01')

# %%
# ── ARCHIVED (original cell 93) ──
df.to_csv('cleaned_retail_2.csv', index=False )

# %% [markdown]
# ### Group 15 — print with syntax error: extra dot and underscore

# %%
# ── ARCHIVED (original cell 98) ──
print(df.['invoice_date'].max()_)
